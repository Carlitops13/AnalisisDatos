# %% [markdown]
# # Clase 3

# %% [markdown]
# #### Instalamos Pandas

# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\stalin\appdata\local\programs\python\python313\lib\site-packages (2.3.3)Note: you may need to restart the kernel to use updated packages.
#
# Requirement already satisfied: numpy>=1.26.0 in c:\users\stalin\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2.3.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\stalin\appdata\roaming\python\python313\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\stalin\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\stalin\appdata\local\programs\python\python313\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\stalin\appdata\roaming\python\python313\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# * Importando Pandas

# %%
import pandas as pd

# %% [markdown]
# * Creacion de Data Frame

# %%
data = {
    "apples": [3,2,1,0],
    "oranges": [9,8,7,5]
}

# %%
data
# Out:
# {'apples': [3, 2, 1, 0], 'oranges': [9, 8, 7, 5]}

# %%
index = ["Carlos", "Ana", "Juan", "Gaby"]

# %%
df = pd.DataFrame(data,index=index)

# %%
df
# Out:
#         apples  oranges
# Carlos       3        9
# Ana          2        8
# Juan         1        7
# Gaby         0        5

# %% [markdown]
# * Crear un data frame de calificaciones

# %%
calificaciones = {
    "Lubswer":[10,10,10,9,6],
    "Alumno1":[8,9,6,10,10],
    "Alumno2":[9,5,9,7,8]
}

# %%
calificaciones
# Out:
# {'Lubswer': [10, 10, 10, 9, 6],
#  'Alumno1': [8, 9, 6, 10, 10],
#  'Alumno2': [9, 5, 9, 7, 8]}

# %%
index2 = ["nota1","nota2","nota3","nota4","nota5"]

# %%
df = pd.DataFrame(calificaciones,index = index2)

# %%
df
# Out:
#        Lubswer  Alumno1  Alumno2
# nota1       10        8        9
# nota2       10        9        5
# nota3       10        6        9
# nota4        9       10        7
# nota5        6       10        8

# %%
df.loc['nota1']
# Out:
# Lubswer    10
# Alumno1     8
# Alumno2     9
# Name: nota1, dtype: int64

# %% [markdown]
# * Guardar Data Frame

# %%
df.to_csv("Notitas.csv")

# %% [markdown]
# * Guardando en Json

# %%
df.to_json("Listado.json")

# %% [markdown]
# * Cargando desde csv y json

# %%
df1 = pd.read_json("Listado.json")

# %%
df2 = pd.read_csv("Notitas.csv", index_col=0)

# %%
df1
# Out:
#        Lubswer  Alumno1  Alumno2
# nota1       10        8        9
# nota2       10        9        5
# nota3       10        6        9
# nota4        9       10        7
# nota5        6       10        8

# %%
df2
# Out:
#        Lubswer  Alumno1  Alumno2
# nota1       10        8        9
# nota2       10        9        5
# nota3       10        6        9
# nota4        9       10        7
# nota5        6       10        8

# %% [markdown]
# ### SQLite

# %% [markdown]
# * Conexión con una base de datos:

# %%
#pip install pysqlite3 ya viene instalado

# %% [markdown]
# * Importar sqlite3

# %%
import sqlite3

# %%
con = sqlite3.connect("database.db")

# %%
df = pd.read_sql_query("SELECT * FROM compras", con)

# %%
df
# Out:
#     index  apples  oranges
# 0    None     NaN      NaN
# 1   MILKA     3.0      2.0
# 2  LUBWER     1.0      1.0

# %%
df1 = pd.read_sql_query("SELECT * FROM notas", con)

# %%
df1
# Out:
#    Alumnos  Programacion  Análisis  Bases de Datos  Etica
# 0  Carlos              8         5               7      8
# 1    Milka             9         4               4      7
# 2    Bryan             5         3               6      7
# 3     Alan             0         8               3      8

# %% [markdown]
# * DataFrame Peliculas

# %%
movies_df = pd.read_csv("IMDB-Movie-Data.csv", index_col="Title")

# %%
movies_df
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
# ...                       ...                       ...
# Secret in Their Eyes      996       Crime,Drama,Mystery
# Hostel: Part II           997                    Horror
# Step Up 2: The Streets    998       Drama,Music,Romance
# Search Party              999          Adventure,Comedy
# Nine Lives               1000     Comedy,Family,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
# ...                                                                    ...
# Secret in Their Eyes     A tight-knit team of rising investigators, alo...
# Hostel: Part II          Three American college students studying abroa...
# Step Up 2: The Streets   Romantic sparks occur between two dance studen...
# Search Party             A pair of friends embark on a mission to reuni...
# Nine Lives               A stuffy businessman finds himself trapped ins...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# Split                      M. Night Shyamalan
# Sing                     Christophe Lourdelet
# Suicide Squad                      David Ayer
# ...                                       ...
# Secret in Their Eyes                Billy Ray
# Hostel: Part II                      Eli Roth
# Step Up 2: The Streets             Jon M. Chu
# Search Party                   Scot Armstrong
# Nine Lives                   Barry Sonnenfeld
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Split                    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Sing                     Matthew McConaughey,Reese Witherspoon, Seth Ma...
# Suicide Squad            Will Smith, Jared Leto, Margot Robbie, Viola D...
# ...                                                                    ...
# Secret in Their Eyes     Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...
# Hostel: Part II          Lauren German, Heather Matarazzo, Bijou Philli...
# Step Up 2: The Streets   Robert Hoffman, Briana Evigan, Cassie Ventura,...
# Search Party             Adam Pally, T.J. Miller, Thomas Middleditch,Sh...
# Nine Lives               Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...
#
#                          Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Guardians of the Galaxy  2014                121     8.1  757074
# Prometheus               2012                124     7.0  485820
# Split                    2016                117     7.3  157606
# Sing                     2016                108     7.2   60545
# Suicide Squad            2016                123     6.2  393727
# ...                       ...                ...     ...     ...
# Secret in Their Eyes     2015                111     6.2   27585
# Hostel: Part II          2007                 94     5.5   73152
# Step Up 2: The Streets   2008                 98     6.2   70699
# Search Party             2014                 93     5.6    4881
# Nine Lives               2016                 87     5.3   12435
#
#                          Revenue (Millions)  Metascore
# Title
# Guardians of the Galaxy              333.13       76.0
# Prometheus                           126.46       65.0
# Split                                138.12       62.0
# Sing                                 270.32       59.0
# Suicide Squad                        325.02       40.0
# ...                                     ...        ...
# Secret in Their Eyes                    NaN       45.0
# Hostel: Part II                       17.54       46.0
# Step Up 2: The Streets                58.01       50.0
# Search Party                            NaN       22.0
# Nine Lives                            19.64       11.0
#
# [1000 rows x 11 columns]

# %%
movies_df.head()
# Out:
#                          Rank                     Genre  \
# Title
# Guardians of the Galaxy     1   Action,Adventure,Sci-Fi
# Prometheus                  2  Adventure,Mystery,Sci-Fi
# Split                       3           Horror,Thriller
# Sing                        4   Animation,Comedy,Family
# Suicide Squad               5  Action,Adventure,Fantasy
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# Prometheus               Following clues to the origin of mankind, a te...
# Split                    Three girls are kidnapped by a man with a diag...
# Sing                     In a city of humanoid animals, a hustling thea...
# Suicide Squad            A secret government agency recruits some of th...
#
#                                      Director  \
# Title
# Guardians of the Galaxy            James Gunn
# Prometheus                       Ridley Scott
# Split                      M. Night Shyamalan
# Sing                     Christophe Lourdelet
# Suicide Squad                      David Ayer
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# Prometheus               Noomi Rapace, Logan Marshall-Green, Michael Fa...
# Split                    James McAvoy, Anya Taylor-Joy, Haley Lu Richar...
# Sing                     Matthew McConaughey,Reese Witherspoon, Seth Ma...
# Suicide Squad            Will Smith, Jared Leto, Margot Robbie, Viola D...
#
#                          Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Guardians of the Galaxy  2014                121     8.1  757074
# Prometheus               2012                124     7.0  485820
# Split                    2016                117     7.3  157606
# Sing                     2016                108     7.2   60545
# Suicide Squad            2016                123     6.2  393727
#
#                          Revenue (Millions)  Metascore
# Title
# Guardians of the Galaxy              333.13       76.0
# Prometheus                           126.46       65.0
# Split                                138.12       62.0
# Sing                                 270.32       59.0
# Suicide Squad                        325.02       40.0

# %%
movies_df.tail()
# Out:
#                         Rank                  Genre  \
# Title
# Secret in Their Eyes     996    Crime,Drama,Mystery
# Hostel: Part II          997                 Horror
# Step Up 2: The Streets   998    Drama,Music,Romance
# Search Party             999       Adventure,Comedy
# Nine Lives              1000  Comedy,Family,Fantasy
#
#                                                               Description  \
# Title
# Secret in Their Eyes    A tight-knit team of rising investigators, alo...
# Hostel: Part II         Three American college students studying abroa...
# Step Up 2: The Streets  Romantic sparks occur between two dance studen...
# Search Party            A pair of friends embark on a mission to reuni...
# Nine Lives              A stuffy businessman finds himself trapped ins...
#
#                                 Director  \
# Title
# Secret in Their Eyes           Billy Ray
# Hostel: Part II                 Eli Roth
# Step Up 2: The Streets        Jon M. Chu
# Search Party              Scot Armstrong
# Nine Lives              Barry Sonnenfeld
#
#                                                                    Actors  \
# Title
# Secret in Their Eyes    Chiwetel Ejiofor, Nicole Kidman, Julia Roberts...
# Hostel: Part II         Lauren German, Heather Matarazzo, Bijou Philli...
# Step Up 2: The Streets  Robert Hoffman, Briana Evigan, Cassie Ventura,...
# Search Party            Adam Pally, T.J. Miller, Thomas Middleditch,Sh...
# Nine Lives              Kevin Spacey, Jennifer Garner, Robbie Amell,Ch...
#
#                         Year  Runtime (Minutes)  Rating  Votes  \
# Title
# Secret in Their Eyes    2015                111     6.2  27585
# Hostel: Part II         2007                 94     5.5  73152
# Step Up 2: The Streets  2008                 98     6.2  70699
# Search Party            2014                 93     5.6   4881
# Nine Lives              2016                 87     5.3  12435
#
#                         Revenue (Millions)  Metascore
# Title
# Secret in Their Eyes                   NaN       45.0
# Hostel: Part II                      17.54       46.0
# Step Up 2: The Streets               58.01       50.0
# Search Party                           NaN       22.0
# Nine Lives                           19.64       11.0

# %% [markdown]
# * Informacion de DATAFRAME

# %%
movies_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1000 entries, Guardians of the Galaxy to Nine Lives
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Rank                1000 non-null   int64
#  1   Genre               1000 non-null   object
#  2   Description         1000 non-null   object
#  3   Director            1000 non-null   object
#  4   Actors              1000 non-null   object
#  5   Year                1000 non-null   int64
#  6   Runtime (Minutes)   1000 non-null   int64
#  7   Rating              1000 non-null   float64
#  8   Votes               1000 non-null   int64
#  9   Revenue (Millions)  872 non-null    float64
#  10  Metascore           936 non-null    float64
# dtypes: float64(3), int64(4), object(4)
# memory usage: 93.8+ KB

# %% [markdown]
# * Dimensiones

# %%
movies_df.shape
# Out:
# (1000, 11)

# %% [markdown]
# **Manejo de duplicados:**

# %% [markdown]
#  * Primero vamos a duplicar el contenido del dataset

# %%
temp_df = pd.concat([movies_df,movies_df])

# %% [markdown]
# * Comprobamos las dimensiones:

# %%
temp_df.shape
# Out:
# (2000, 11)

# %% [markdown]
# * Eliminar duplicados

# %%
temp_df = temp_df.drop_duplicates()

# %%
temp_df.shape
# Out:
# (1000, 11)

# %% [markdown]
# ##### Manejo de valores vacíos

# %% [markdown]
# * Buscamos si existen valores vacío:

# %%
movies_df.isnull()
# Out:
#                           Rank  Genre  Description  Director  Actors   Year  \
# Title
# Guardians of the Galaxy  False  False        False     False   False  False
# Prometheus               False  False        False     False   False  False
# Split                    False  False        False     False   False  False
# Sing                     False  False        False     False   False  False
# Suicide Squad            False  False        False     False   False  False
# ...                        ...    ...          ...       ...     ...    ...
# Secret in Their Eyes     False  False        False     False   False  False
# Hostel: Part II          False  False        False     False   False  False
# Step Up 2: The Streets   False  False        False     False   False  False
# Search Party             False  False        False     False   False  False
# Nine Lives               False  False        False     False   False  False
#
#                          Runtime (Minutes)  Rating  Votes  Revenue (Millions)  \
# Title
# Guardians of the Galaxy              False   False  False               False
# Prometheus                           False   False  False               False
# Split                                False   False  False               False
# Sing                                 False   False  False               False
# Suicide Squad                        False   False  False               False
# ...                                    ...     ...    ...                 ...
# Secret in Their Eyes                 False   False  False                True
# Hostel: Part II                      False   False  False               False
# Step Up 2: The Streets               False   False  False               False
# Search Party                         False   False  False                True
# Nine Lives                           False   False  False               False
#
#                          Metascore
# Title
# Guardians of the Galaxy      False
# Prometheus                   False
# Split                        False
# Sing                         False
# Suicide Squad                False
# ...                            ...
# Secret in Their Eyes         False
# Hostel: Part II              False
# Step Up 2: The Streets       False
# Search Party                 False
# Nine Lives                   False
#
# [1000 rows x 11 columns]

# %% [markdown]
# * Sumarizamos

# %%
movies_df.isnull().sum()
# Out:
# Rank                    0
# Genre                   0
# Description             0
# Director                0
# Actors                  0
# Year                    0
# Runtime (Minutes)       0
# Rating                  0
# Votes                   0
# Revenue (Millions)    128
# Metascore              64
# dtype: int64

# %%
m2 = movies_df.dropna()

# %%
m2.isnull().sum()
# Out:
# Rank                  0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %% [markdown]
# * Por lo general lo que se hace es llenar con valores tales como la media o mediana:

# %%
revenue = movies_df['Revenue (Millions)']

# %%
revenue
# Out:
# Title
# Guardians of the Galaxy    333.13
# Prometheus                 126.46
# Split                      138.12
# Sing                       270.32
# Suicide Squad              325.02
#                             ...
# Secret in Their Eyes          NaN
# Hostel: Part II             17.54
# Step Up 2: The Streets      58.01
# Search Party                  NaN
# Nine Lives                  19.64
# Name: Revenue (Millions), Length: 1000, dtype: float64

# %%
revenue_mean = revenue.mean()

# %%
revenue_mean
# Out:
# np.float64(82.95637614678898)

# %%
revenue.fillna(revenue_mean, inplace=True)

# %%
movies_df.isnull().sum()
# Out:
# Rank                   0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Year                   0
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue (Millions)     0
# Metascore             64
# dtype: int64

# %% [markdown]
# * Reemplazar columnas de metascore

# %%
metascore = movies_df['Metascore']

# %%
metascore
# Out:
# Title
# Guardians of the Galaxy    76.0
# Prometheus                 65.0
# Split                      62.0
# Sing                       59.0
# Suicide Squad              40.0
#                            ...
# Secret in Their Eyes       45.0
# Hostel: Part II            46.0
# Step Up 2: The Streets     50.0
# Search Party               22.0
# Nine Lives                 11.0
# Name: Metascore, Length: 1000, dtype: float64

# %%
metascore_mean = metascore.mean()

# %%
metascore_mean
# Out:
# np.float64(58.98504273504273)

# %%
movies_df.isnull().sum()
# Out:
# Rank                   0
# Genre                  0
# Description            0
# Director               0
# Actors                 0
# Year                   0
# Runtime (Minutes)      0
# Rating                 0
# Votes                  0
# Revenue (Millions)     0
# Metascore             64
# dtype: int64

# %%
metascore.fillna(metascore_mean, inplace=True)

# %%
movies_df.isnull().sum()
# Out:
# Rank                  0
# Genre                 0
# Description           0
# Director              0
# Actors                0
# Year                  0
# Runtime (Minutes)     0
# Rating                0
# Votes                 0
# Revenue (Millions)    0
# Metascore             0
# dtype: int64

# %%
movies_df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)    Metascore
# count         1000.000000  1000.000000
# mean            82.956376    58.985043
# std             96.412043    16.634858
# min              0.000000    11.000000
# 25%             17.442500    47.750000
# 50%             60.375000    58.985043
# 75%             99.177500    71.000000
# max            936.630000   100.000000

# %% [markdown]
# * Ejercicio de importar el json

# %%
carros = pd.read_json("output.json")

# %%
carros
# Out:
#    id       marca    modelo   año                 tipo         color  \
# 0   1      Toyota   Corolla  2021                Sedán        Blanco
# 1   2       Honda     Civic  2022                Sedán         Negro
# 2   3        Ford    Ranger  2020               Pickup          Rojo
# 3   4   Chevrolet   Tracker  2023                  SUV          Gris
# 4   5     Hyundai    Tucson  2021                  SUV          Azul
# 5   6         Kia  Sportage  2022                  SUV      Plateado
# 6   7       Tesla   Model 3  2023      Sedán Eléctrico  Blanco Perla
# 7   8      Nissan      Leaf  2022  Hatchback Eléctrico         Verde
# 8   9       Mazda      CX-5  2021                  SUV          Rojo
# 9  10  Volkswagen    Amarok  2020               Pickup         Negro
#
#               motor combustible  precio
# 0              1.8L    Gasolina   23000
# 1              2.0L    Gasolina   25000
# 2     2.3L EcoBoost      Diésel   32000
# 3        1.2L Turbo    Gasolina   28000
# 4              2.5L    Gasolina   31000
# 5              2.0L    Gasolina   29500
# 6         Eléctrico   Eléctrico   42000
# 7  Eléctrico 110 kW   Eléctrico   31000
# 8              2.5L    Gasolina   33000
# 9       3.0L V6 TDI      Diésel   37000

# %%
carros.to_sql("Autos",con)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[61], line 1
# ----> 1 carros.to_sql("Autos",con)
#
# File c:\Users\Stalin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\util\_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File c:\Users\Stalin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:3109, in NDFrame.to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype, method)
#    2911 """
#    2912 Write records stored in a DataFrame to a SQL database.
#    2913
#    (...)
#    3105 [(1,), (None,), (2,)]
#    3106 """  # noqa: E501
#    3107 from pandas.io import sql
# -> 3109 return sql.to_sql(
#    3110     self,
#    3111     name,
#    3112     con,
#    3113     schema=schema,
#    3114     if_exists=if_exists,
#    3115     index=index,
#    3116     index_label=index_label,
#    3117     chunksize=chunksize,
#    3118     dtype=dtype,
#    3119     method=method,
#    3120 )
#
# File c:\Users\Stalin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:844, in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype, method, engine, **engine_kwargs)
#     839     raise NotImplementedError(
#     840         "'frame' argument should be either a Series or a DataFrame"
#     841     )
#     843 with pandasSQL_builder(con, schema=schema, need_transaction=True) as pandas_sql:
# --> 844     return pandas_sql.to_sql(
#     845         frame,
#     846         name,
#     847         if_exists=if_exists,
#     848         index=index,
#     849         index_label=index_label,
#     850         schema=schema,
#     851         chunksize=chunksize,
#     852         dtype=dtype,
#     853         method=method,
#     854         engine=engine,
#     855         **engine_kwargs,
#     856     )
#
# File c:\Users\Stalin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:2840, in SQLiteDatabase.to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype, method, engine, **engine_kwargs)
#    2829             raise ValueError(f"{col} ({my_type}) not a string")
#    2831 table = SQLiteTable(
#    2832     name,
#    2833     self,
#    (...)
#    2838     dtype=dtype,
#    2839 )
# -> 2840 table.create()
#    2841 return table.insert(chunksize, method)
#
# File c:\Users\Stalin\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\io\sql.py:988, in SQLTable.create(self)
#     986 if self.exists():
#     987     if self.if_exists == "fail":
# --> 988         raise ValueError(f"Table '{self.name}' already exists.")
#     989     if self.if_exists == "replace":
#     990         self.pd_sql.drop_table(self.name, self.schema)
#
# ValueError: Table 'Autos' already exists.

# %%
movies_df.describe()
# Out:
#               Rank         Year  Runtime (Minutes)       Rating         Votes  \
# count  1000.000000  1000.000000        1000.000000  1000.000000  1.000000e+03
# mean    500.500000  2012.783000         113.172000     6.723200  1.698083e+05
# std     288.819436     3.205962          18.810908     0.945429  1.887626e+05
# min       1.000000  2006.000000          66.000000     1.900000  6.100000e+01
# 25%     250.750000  2010.000000         100.000000     6.200000  3.630900e+04
# 50%     500.500000  2014.000000         111.000000     6.800000  1.107990e+05
# 75%     750.250000  2016.000000         123.000000     7.400000  2.399098e+05
# max    1000.000000  2016.000000         191.000000     9.000000  1.791916e+06
#
#        Revenue (Millions)    Metascore
# count         1000.000000  1000.000000
# mean            82.956376    58.985043
# std             96.412043    16.634858
# min              0.000000    11.000000
# 25%             17.442500    47.750000
# 50%             60.375000    58.985043
# 75%             99.177500    71.000000
# max            936.630000   100.000000

# %% [markdown]
# * Filtar por generos

# %%
movies_df["Genre"].describe()

# %%
movies_df["Genre"].value_counts().head(20)

# %% [markdown]
# * Me muestre el mayor reaingtin y ademas me de solo las necesarias

# %%
movies_df[movies_df["Rating"] >= 8.6].head(3)

# %% [markdown]
# * Las peores

# %%
movies_df[movies_df["Rating"] <= 4 ].tail(15)

# %%
movies_df[(movies_df["Year"] >= 2000) & (movies_df["Revenue (Millions)"] > 0) & (movies_df["Rating"] >= 8)].head(3)
# Out:
#                          Rank                    Genre  \
# Title
# Guardians of the Galaxy     1  Action,Adventure,Sci-Fi
# La La Land                  7       Comedy,Drama,Music
# Hacksaw Ridge              17  Biography,Drama,History
#
#                                                                Description  \
# Title
# Guardians of the Galaxy  A group of intergalactic criminals are forced ...
# La La Land               A jazz pianist falls for an aspiring actress i...
# Hacksaw Ridge            WWII American Army Medic Desmond T. Doss, who ...
#
#                                 Director  \
# Title
# Guardians of the Galaxy       James Gunn
# La La Land               Damien Chazelle
# Hacksaw Ridge                 Mel Gibson
#
#                                                                     Actors  \
# Title
# Guardians of the Galaxy  Chris Pratt, Vin Diesel, Bradley Cooper, Zoe S...
# La La Land               Ryan Gosling, Emma Stone, Rosemarie DeWitt, J....
# Hacksaw Ridge            Andrew Garfield, Sam Worthington, Luke Bracey,...
#
#                          Year  Runtime (Minutes)  Rating   Votes  \
# Title
# Guardians of the Galaxy  2014                121     8.1  757074
# La La Land               2016                128     8.3  258682
# Hacksaw Ridge            2016                139     8.2  211760
#
#                          Revenue (Millions)  Metascore
# Title
# Guardians of the Galaxy              333.13       76.0
# La La Land                           151.06       93.0
# Hacksaw Ridge                         67.12       71.0

# %%
movies_df[(movies_df["Year"] >= 2000) & (movies_df["Runtime (Minutes)"] < 10000) & (movies_df["Rating"] <= 5)].tail(3)

# %%
print(movies_df.columns)
# Out:
# Index(['Rank', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')

# %% [markdown]
# * Importar otro

# %%
games = pd.read_csv("Videojuegos.csv", index_col = "Name")

# %%
games.columns
# Out:
# Index(['Platform', 'Year_of_Release', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales', 'Critic_Score',
#        'Critic_Count', 'User_Score', 'User_Count', 'Developer', 'Rating'],
#       dtype='object')

# %%
games
# Out:
#                               Platform  Year_of_Release         Genre  \
# Name
# Wii Sports                         Wii           2006.0        Sports
# Super Mario Bros.                  NES           1985.0      Platform
# Mario Kart Wii                     Wii           2008.0        Racing
# Wii Sports Resort                  Wii           2009.0        Sports
# Pokemon Red/Pokemon Blue            GB           1996.0  Role-Playing
# ...                                ...              ...           ...
# Samurai Warriors: Sanada Maru      PS3           2016.0        Action
# LMA Manager 2007                  X360           2006.0        Sports
# Haitaka no Psychedelica            PSV           2016.0     Adventure
# Spirits & Spells                   GBA           2003.0      Platform
# Winning Post 8 2016                PSV           2016.0    Simulation
#
#                                   Publisher  NA_Sales  EU_Sales  JP_Sales  \
# Name
# Wii Sports                         Nintendo     41.36     28.96      3.77
# Super Mario Bros.                  Nintendo     29.08      3.58      6.81
# Mario Kart Wii                     Nintendo     15.68     12.76      3.79
# Wii Sports Resort                  Nintendo     15.61     10.93      3.28
# Pokemon Red/Pokemon Blue           Nintendo     11.27      8.89     10.22
# ...                                     ...       ...       ...       ...
# Samurai Warriors: Sanada Maru    Tecmo Koei      0.00      0.00      0.01
# LMA Manager 2007                Codemasters      0.00      0.01      0.00
# Haitaka no Psychedelica        Idea Factory      0.00      0.00      0.01
# Spirits & Spells                    Wanadoo      0.01      0.00      0.00
# Winning Post 8 2016              Tecmo Koei      0.00      0.00      0.01
#
#                                Other_Sales  Global_Sales  Critic_Score  \
# Name
# Wii Sports                            8.45         82.53          76.0
# Super Mario Bros.                     0.77         40.24           NaN
# Mario Kart Wii                        3.29         35.52          82.0
# Wii Sports Resort                     2.95         32.77          80.0
# Pokemon Red/Pokemon Blue              1.00         31.37           NaN
# ...                                    ...           ...           ...
# Samurai Warriors: Sanada Maru         0.00          0.01           NaN
# LMA Manager 2007                      0.00          0.01           NaN
# Haitaka no Psychedelica               0.00          0.01           NaN
# Spirits & Spells                      0.00          0.01           NaN
# Winning Post 8 2016                   0.00          0.01           NaN
#
#                                Critic_Count User_Score  User_Count Developer  \
# Name
# Wii Sports                             51.0          8       322.0  Nintendo
# Super Mario Bros.                       NaN        NaN         NaN       NaN
# Mario Kart Wii                         73.0        8.3       709.0  Nintendo
# Wii Sports Resort                      73.0          8       192.0  Nintendo
# Pokemon Red/Pokemon Blue                NaN        NaN         NaN       NaN
# ...                                     ...        ...         ...       ...
# Samurai Warriors: Sanada Maru           NaN        NaN         NaN       NaN
# LMA Manager 2007                        NaN        NaN         NaN       NaN
# Haitaka no Psychedelica                 NaN        NaN         NaN       NaN
# Spirits & Spells                        NaN        NaN         NaN       NaN
# Winning Post 8 2016                     NaN        NaN         NaN       NaN
#
#                               Rating
# Name
# Wii Sports                         E
# Super Mario Bros.                NaN
# Mario Kart Wii                     E
# Wii Sports Resort                  E
# Pokemon Red/Pokemon Blue         NaN
# ...                              ...
# Samurai Warriors: Sanada Maru    NaN
# LMA Manager 2007                 NaN
# Haitaka no Psychedelica          NaN
# Spirits & Spells                 NaN
# Winning Post 8 2016              NaN
#
# [16719 rows x 15 columns]

# %%
games[ (games["Global_Sales"] <= 50 )].tail(20)
# Out:
#                                                    Platform  Year_of_Release  \
# Name
# Planet Monsters                                         GBA           2001.0
# Breach                                                   PC           2011.0
# Bust-A-Move 3000                                         GC           2003.0
# Mega Brain Boost                                         DS           2008.0
# The Longest 5 Minutes                                   PSV           2016.0
# Mezase!! Tsuri Master DS                                 DS           2009.0
# Eiyuu Densetsu: Sora no Kiseki Material Collect...      PSP           2007.0
# STORM: Frontline Nation                                  PC           2011.0
# Strawberry Nauts                                        PSV           2016.0
# Plushees                                                 DS           2008.0
# 15 Days                                                  PC           2009.0
# Men in Black II: Alien Escape                            GC           2003.0
# Aiyoku no Eustia                                        PSV           2014.0
# Woody Woodpecker in Crazy Castle 5                      GBA           2002.0
# SCORE International Baja 1000: The Official Game        PS2           2008.0
# Samurai Warriors: Sanada Maru                           PS3           2016.0
# LMA Manager 2007                                       X360           2006.0
# Haitaka no Psychedelica                                 PSV           2016.0
# Spirits & Spells                                        GBA           2003.0
# Winning Post 8 2016                                     PSV           2016.0
#
#                                                            Genre  \
# Name
# Planet Monsters                                           Action
# Breach                                                   Shooter
# Bust-A-Move 3000                                          Puzzle
# Mega Brain Boost                                          Puzzle
# The Longest 5 Minutes                                     Action
# Mezase!! Tsuri Master DS                                  Sports
# Eiyuu Densetsu: Sora no Kiseki Material Collect...  Role-Playing
# STORM: Frontline Nation                                 Strategy
# Strawberry Nauts                                       Adventure
# Plushees                                              Simulation
# 15 Days                                                Adventure
# Men in Black II: Alien Escape                            Shooter
# Aiyoku no Eustia                                            Misc
# Woody Woodpecker in Crazy Castle 5                      Platform
# SCORE International Baja 1000: The Official Game          Racing
# Samurai Warriors: Sanada Maru                             Action
# LMA Manager 2007                                          Sports
# Haitaka no Psychedelica                                Adventure
# Spirits & Spells                                        Platform
# Winning Post 8 2016                                   Simulation
#
#                                                                 Publisher  \
# Name
# Planet Monsters                                                     Titus
# Breach                                                          Destineer
# Bust-A-Move 3000                                                  Ubisoft
# Mega Brain Boost                                    Majesco Entertainment
# The Longest 5 Minutes                                Nippon Ichi Software
# Mezase!! Tsuri Master DS                                      Hudson Soft
# Eiyuu Densetsu: Sora no Kiseki Material Collect...     Falcom Corporation
# STORM: Frontline Nation                                           Unknown
# Strawberry Nauts                                                  Unknown
# Plushees                                                        Destineer
# 15 Days                                                 DTP Entertainment
# Men in Black II: Alien Escape                                  Infogrames
# Aiyoku no Eustia                                          dramatic create
# Woody Woodpecker in Crazy Castle 5                                  Kemco
# SCORE International Baja 1000: The Official Game               Activision
# Samurai Warriors: Sanada Maru                                  Tecmo Koei
# LMA Manager 2007                                              Codemasters
# Haitaka no Psychedelica                                      Idea Factory
# Spirits & Spells                                                  Wanadoo
# Winning Post 8 2016                                            Tecmo Koei
#
#                                                     NA_Sales  EU_Sales  \
# Name
# Planet Monsters                                         0.01      0.00
# Breach                                                  0.01      0.00
# Bust-A-Move 3000                                        0.01      0.00
# Mega Brain Boost                                        0.01      0.00
# The Longest 5 Minutes                                   0.00      0.00
# Mezase!! Tsuri Master DS                                0.00      0.00
# Eiyuu Densetsu: Sora no Kiseki Material Collect...      0.00      0.00
# STORM: Frontline Nation                                 0.00      0.01
# Strawberry Nauts                                        0.00      0.00
# Plushees                                                0.01      0.00
# 15 Days                                                 0.00      0.01
# Men in Black II: Alien Escape                           0.01      0.00
# Aiyoku no Eustia                                        0.00      0.00
# Woody Woodpecker in Crazy Castle 5                      0.01      0.00
# SCORE International Baja 1000: The Official Game        0.00      0.00
# Samurai Warriors: Sanada Maru                           0.00      0.00
# LMA Manager 2007                                        0.00      0.01
# Haitaka no Psychedelica                                 0.00      0.00
# Spirits & Spells                                        0.01      0.00
# Winning Post 8 2016                                     0.00      0.00
#
#                                                     JP_Sales  Other_Sales  \
# Name
# Planet Monsters                                         0.00          0.0
# Breach                                                  0.00          0.0
# Bust-A-Move 3000                                        0.00          0.0
# Mega Brain Boost                                        0.00          0.0
# The Longest 5 Minutes                                   0.01          0.0
# Mezase!! Tsuri Master DS                                0.01          0.0
# Eiyuu Densetsu: Sora no Kiseki Material Collect...      0.01          0.0
# STORM: Frontline Nation                                 0.00          0.0
# Strawberry Nauts                                        0.01          0.0
# Plushees                                                0.00          0.0
# 15 Days                                                 0.00          0.0
# Men in Black II: Alien Escape                           0.00          0.0
# Aiyoku no Eustia                                        0.01          0.0
# Woody Woodpecker in Crazy Castle 5                      0.00          0.0
# SCORE International Baja 1000: The Official Game        0.00          0.0
# Samurai Warriors: Sanada Maru                           0.01          0.0
# LMA Manager 2007                                        0.00          0.0
# Haitaka no Psychedelica                                 0.01          0.0
# Spirits & Spells                                        0.00          0.0
# Winning Post 8 2016                                     0.01          0.0
#
#                                                     Global_Sales  \
# Name
# Planet Monsters                                             0.01
# Breach                                                      0.01
# Bust-A-Move 3000                                            0.01
# Mega Brain Boost                                            0.01
# The Longest 5 Minutes                                       0.01
# Mezase!! Tsuri Master DS                                    0.01
# Eiyuu Densetsu: Sora no Kiseki Material Collect...          0.01
# STORM: Frontline Nation                                     0.01
# Strawberry Nauts                                            0.01
# Plushees                                                    0.01
# 15 Days                                                     0.01
# Men in Black II: Alien Escape                               0.01
# Aiyoku no Eustia                                            0.01
# Woody Woodpecker in Crazy Castle 5                          0.01
# SCORE International Baja 1000: The Official Game            0.01
# Samurai Warriors: Sanada Maru                               0.01
# LMA Manager 2007                                            0.01
# Haitaka no Psychedelica                                     0.01
# Spirits & Spells                                            0.01
# Winning Post 8 2016                                         0.01
#
#                                                     Critic_Score  \
# Name
# Planet Monsters                                             67.0
# Breach                                                      61.0
# Bust-A-Move 3000                                            53.0
# Mega Brain Boost                                            48.0
# The Longest 5 Minutes                                        NaN
# Mezase!! Tsuri Master DS                                     NaN
# Eiyuu Densetsu: Sora no Kiseki Material Collect...           NaN
# STORM: Frontline Nation                                     60.0
# Strawberry Nauts                                             NaN
# Plushees                                                     NaN
# 15 Days                                                     63.0
# Men in Black II: Alien Escape                                NaN
# Aiyoku no Eustia                                             NaN
# Woody Woodpecker in Crazy Castle 5                           NaN
# SCORE International Baja 1000: The Official Game             NaN
# Samurai Warriors: Sanada Maru                                NaN
# LMA Manager 2007                                             NaN
# Haitaka no Psychedelica                                      NaN
# Spirits & Spells                                             NaN
# Winning Post 8 2016                                          NaN
#
#                                                     Critic_Count User_Score  \
# Name
# Planet Monsters                                              9.0        tbd
# Breach                                                      12.0        5.8
# Bust-A-Move 3000                                             4.0        tbd
# Mega Brain Boost                                            10.0        tbd
# The Longest 5 Minutes                                        NaN        NaN
# Mezase!! Tsuri Master DS                                     NaN        NaN
# Eiyuu Densetsu: Sora no Kiseki Material Collect...           NaN        NaN
# STORM: Frontline Nation                                     12.0        7.2
# Strawberry Nauts                                             NaN        NaN
# Plushees                                                     NaN        tbd
# 15 Days                                                      6.0        5.8
# Men in Black II: Alien Escape                                NaN        tbd
# Aiyoku no Eustia                                             NaN        NaN
# Woody Woodpecker in Crazy Castle 5                           NaN        NaN
# SCORE International Baja 1000: The Official Game             NaN        NaN
# Samurai Warriors: Sanada Maru                                NaN        NaN
# LMA Manager 2007                                             NaN        NaN
# Haitaka no Psychedelica                                      NaN        NaN
# Spirits & Spells                                             NaN        NaN
# Winning Post 8 2016                                          NaN        NaN
#
#                                                     User_Count  \
# Name
# Planet Monsters                                            NaN
# Breach                                                    43.0
# Bust-A-Move 3000                                           NaN
# Mega Brain Boost                                           NaN
# The Longest 5 Minutes                                      NaN
# Mezase!! Tsuri Master DS                                   NaN
# Eiyuu Densetsu: Sora no Kiseki Material Collect...         NaN
# STORM: Frontline Nation                                   13.0
# Strawberry Nauts                                           NaN
# Plushees                                                   NaN
# 15 Days                                                    8.0
# Men in Black II: Alien Escape                              NaN
# Aiyoku no Eustia                                           NaN
# Woody Woodpecker in Crazy Castle 5                         NaN
# SCORE International Baja 1000: The Official Game           NaN
# Samurai Warriors: Sanada Maru                              NaN
# LMA Manager 2007                                           NaN
# Haitaka no Psychedelica                                    NaN
# Spirits & Spells                                           NaN
# Winning Post 8 2016                                        NaN
#
#                                                              Developer Rating
# Name
# Planet Monsters                                     Planet Interactive      E
# Breach                                                    Atomic Games      T
# Bust-A-Move 3000                                     Taito Corporation      E
# Mega Brain Boost                                    Interchannel-Holon      E
# The Longest 5 Minutes                                              NaN    NaN
# Mezase!! Tsuri Master DS                                           NaN    NaN
# Eiyuu Densetsu: Sora no Kiseki Material Collect...                 NaN    NaN
# STORM: Frontline Nation                                         SimBin   E10+
# Strawberry Nauts                                                   NaN    NaN
# Plushees                                                Big John Games      E
# 15 Days                                              DTP Entertainment    NaN
# Men in Black II: Alien Escape                                    Atari      T
# Aiyoku no Eustia                                                   NaN    NaN
# Woody Woodpecker in Crazy Castle 5                                 NaN    NaN
# SCORE International Baja 1000: The Official Game                   NaN    NaN
# Samurai Warriors: Sanada Maru                                      NaN    NaN
# LMA Manager 2007                                                   NaN    NaN
# Haitaka no Psychedelica                                            NaN    NaN
# Spirits & Spells                                                   NaN    NaN
# Winning Post 8 2016                                                NaN    NaN
